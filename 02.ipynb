# %% [markdown]
# # Funções e POO

# %% [markdown]
# Definindo Funções :

# %%
def f(x):
    return(2 * x) # A função return diz o que  deve retornar 

x: int = f(2)
print(x) #4
# Out:
# 4

# %% [markdown]
# Estrutura da Função

# %%
def NomeFuncao(parametros):
    #corpo da função
    return #retormoda função

# %% [markdown]
# Funções com valores padrões

# %%
def calcular_preco(preco:int , desconto:int = 0 ) -> float:
    valor_final = preco - (preco * desconto / 100)

    return valor_final
